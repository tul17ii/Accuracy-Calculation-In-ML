# %% [markdown]
# <a href="https://colab.research.google.com/github/tul17ii/Accuracy-Calculation-In-ML/blob/main/ACCURACY_CALCULATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import libraries
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Step 2: Load CSV file (upload first in Colab)
from google.colab import files
uploaded = files.upload()

df = pd.read_csv("sentiment_data.csv")
print(df.head())

# Step 3: Preprocess text data
texts = df['text'].values
labels = df['label'].values

# Convert text labels to numbers
le = LabelEncoder()
labels = le.fit_transform(labels)  # positive = 1, negative = 0

# Tokenize text
tokenizer = Tokenizer(num_words=1000, oov_token="<OOV>")
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
padded = pad_sequences(sequences, maxlen=20, padding='post')

# Step 4: Train-test split
X_train, X_test, y_train, y_test = train_test_split(padded, labels, test_size=0.2, random_state=42)

# Step 5: Build Neural Network model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=1000, output_dim=16, input_length=20),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Step 6: Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Step 7: Train model
model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))

# Step 8: Evaluate model
loss, acc = model.evaluate(X_test, y_test)
print(f"\nTest Accuracy: {acc*100:.2f}%")
# Out:
#      <input type="file" id="files-e8823bf0-645a-4b06-8c38-b7344ccd6b7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8823bf0-645a-4b06-8c38-b7344ccd6b7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Load your uploaded CSV file (adjust the filename if needed)
df = pd.read_csv("sentiment_data.csv")  # use exact file name
print(df.head())
# Out:
#    id                                    text     label
# 0   1      I love this movie. It’s fantastic!  positive
# 1   2       The plot was terrible and boring.  negative
# 2   3           What a wonderful performance!  positive
# 3   4  I hated the characters and the acting.  negative
# 4   5         The film was okay, not too bad.  positive

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Encode the sentiment labels (positive → 1, negative → 0)
le = LabelEncoder()
df['label'] = le.fit_transform(df['label'])

# Tokenize the text
tokenizer = Tokenizer(num_words=1000, oov_token="<OOV>")
tokenizer.fit_on_texts(df['text'])
sequences = tokenizer.texts_to_sequences(df['text'])

# Pad the sequences to the same length
padded = pad_sequences(sequences, maxlen=20, padding='post')

X = padded
y = df['label']

# %%
# Make predictions on your input
predictions = model.predict(X)
predicted_labels = (predictions > 0.5).astype("int32").flatten()

# Show predictions with original text
for i in range(len(df)):
    print(f"Text: {df['text'][i]}")
    print(f"Actual: {le.inverse_transform([y[i]])[0]}, Predicted: {le.inverse_transform([predicted_labels[i]])[0]}")
    print("-" * 50)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Text: I love this movie. It’s fantastic!
# Actual: 1, Predicted: 1
# --------------------------------------------------
# Text: The plot was terrible and boring.
# Actual: 0, Predicted: 1
# --------------------------------------------------
# Text: What a wonderful performance!
# Actual: 1, Predicted: 1
# --------------------------------------------------
# Text: I hated the characters and the acting.
# Actual: 0, Predicted: 0
# --------------------------------------------------
# Text: The film was okay, not too bad.
# Actual: 1, Predicted: 1
# --------------------------------------------------
# Text: Absolutely awful experience.
# Actual: 0, Predicted: 0
# --------------------------------------------------
# Text: It was a masterpiece.
# Actual: 1, Predicted: 1
# --------------------------------------------------
# Text: Not worth the time or money.
# Actual: 0, Predicted: 0
# --------------------------------------------------
# ...
